# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('weather_data.csv')
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.replace(-1,np.nan,inplace=True)
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.replace([-1,0,34],np.nan,inplace=True)
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017          NaN        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.replace(
    {
        'temperature':32,
        'windspeed':0,
        'event':'Rain'
    },np.nan,inplace=True)
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017          NaN        6.0     NaN
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017          NaN        NaN     NaN
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017          NaN        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# ### Regular Expression

# %%
df1 = pd.DataFrame({
    'temperature':[34,32,32,31,35,34,'33 C', '56 F']
})
df1
# Out:
#   temperature
# 0          34
# 1          32
# 2          32
# 3          31
# 4          35
# 5          34
# 6        33 C
# 7        56 F

# %% [markdown]
# ## Now to remove characters  from temperature we use Regex

# %%
df1.replace('[A-Za-z]','',regex=True,inplace=True)
df1
# Out:
#   temperature
# 0          34
# 1          32
# 2          32
# 3          31
# 4          35
# 5          34
# 6         33
# 7         56

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  8 non-null      object
# dtypes: object(1)
# memory usage: 196.0+ bytes

# %%
df1['temperature'] = [int(i) for i in df1.temperature]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  8 non-null      int64
# dtypes: int64(1)
# memory usage: 196.0 bytes

# %%
df2 = pd.DataFrame(
    {
        'students':['Ali','Saddar','Azhar','Faisal','Mehar'],
        'score':['Best','Average','Excellent','Poor','Good']
    }
)
df2
# Out:
#   students      score
# 0      Ali       Best
# 1   Saddar    Average
# 2    Azhar  Excellent
# 3   Faisal       Poor
# 4    Mehar       Good

# %%
df.score=df2.replace(['Best','Average','Excellent','Poor','Good'],[4,2,5,1,3])
df2
# Out:
# <ipython-input-21-45e218402fe0>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.score=df2.replace(['Best','Average','Excellent','Poor','Good'],[4,2,5,1,3])
#   students  score
# 0      Ali      4
# 1   Saddar      2
# 2    Azhar      5
# 3   Faisal      1
# 4    Mehar      3
