# %% [markdown]
# Summary
# Here’s a breakdown of what you should focus on while learning Pandas for Data Science:
#
# 1. Data Structures: Learn to use Series and DataFrame.
# 2. Data Loading: Import data from CSV, Excel, JSON, etc.
# 3. Data Cleaning: Handle missing values, duplicates, and incorrect data.
# 4. Data Manipulation: Filter, sort, group, merge, and reshape data.
# 5. Aggregation: Use groupby and pivot tables for aggregating data.
# 6. Functions: Apply custom functions to rows/columns using apply.
# 7. Dates: Work with date and time data.
# 8. Visualization: Plot data using built-in Pandas plotting functions. (line, bar, scatter charts and histogram etc)
# 9. Handling Large Datasets: Use chunking for memory-efficient processing.

# %% [markdown]
# ## 1. Introduction to Pandas
# ### Pandas is a powerful, open-source library for data manipulation and analysis.
# ## It offers two primary data structures:
# ## Series: One-dimensional labeled array, similar to a list or dictionary.
# ## DataFrame: Two-dimensional labeled data structure, similar to a table or spreadsheet.

# %%
import pandas as pd

# %%
data = {'name':['Saddar','Shahid','Mubashir'],
        'roll':[77,78,71],
        'district':['Dadu','Dadu','Larkana']}
df = pd.DataFrame(data)
df
# Out:
#        name  roll district
# 0    Saddar    77     Dadu
# 1    Shahid    78     Dadu
# 2  Mubashir    71  Larkana

# %% [markdown]
# ## Loading data from external files

# %%
df = pd.read_csv('area_prices.csv')
df.head()
# Out:
#    Unnamed: 0  area         prices
# 0           0  1000  316404.109589
# 1           1  1500  384297.945205
# 2           2  2300  492928.082192
# 3           3  3540  661304.794521
# 4           4  4120  740061.643836

# %%
df['Unnamed: 0'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: Unnamed: 0, dtype: int64

# %%
df=pd.read_excel('area_prices.xlsx')
df.head()
# Out:
#    Unnamed: 0  area         prices
# 0           0  1000  316404.109589
# 1           1  1500  384297.945205
# 2           2  2300  492928.082192
# 3           3  3540  661304.794521
# 4           4  4120  740061.643836

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  13 non-null     int64
#  1   area        13 non-null     int64
#  2   prices      13 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 440.0 bytes

# %%
df.describe()
# Out:
#        Unnamed: 0         area        prices
# count    13.00000    13.000000  1.300000e+01
# mean      6.00000  4440.000000  7.835137e+05
# std       3.89444  2547.825871  3.459633e+05
# min       0.00000  1000.000000  3.164041e+05
# 25%       3.00000  2300.000000  4.929281e+05
# 50%       6.00000  4120.000000  7.400616e+05
# 75%       9.00000  5490.000000  9.260908e+05
# max      12.00000  9000.000000  1.402705e+06

# %%
df.shape
# Out:
# (13, 3)

# %% [markdown]
# ### Accessing data

# %% [markdown]
# ## single value

# %%
df['area'][1]
# Out:
# 1500

# %% [markdown]
# ## single row

# %%
df.iloc[0]
# Out:
# Unnamed: 0         0.000000
# area            1000.000000
# prices        316404.109589
# Name: 0, dtype: float64

# %% [markdown]
# ## single column

# %%
df['area']
# Out:
# 0     1000
# 1     1500
# 2     2300
# 3     3540
# 4     4120
# 5     4560
# 6     5490
# 7     3460
# 8     4750
# 9     2300
# 10    9000
# 11    8600
# 12    7100
# Name: area, dtype: int64

# %%
df.loc[0]
# Out:
# Unnamed: 0         0.000000
# area            1000.000000
# prices        316404.109589
# Name: 0, dtype: float64

# %%
df.iloc[1]
# Out:
# Unnamed: 0         1.000000
# area            1500.000000
# prices        384297.945205
# Name: 1, dtype: float64

# %%
df.loc[1]
# Out:
# Unnamed: 0         1.000000
# area            1500.000000
# prices        384297.945205
# Name: 1, dtype: float64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### checking for missing values

# %%
df.isnull()
# Out:
#     Unnamed: 0   area  prices
# 0        False  False   False
# 1        False  False   False
# 2        False  False   False
# 3        False  False   False
# 4        False  False   False
# 5        False  False   False
# 6        False  False   False
# 7        False  False   False
# 8        False  False   False
# 9        False  False   False
# 10       False  False   False
# 11       False  False   False
# 12       False  False   False

# %% [markdown]
# ### dropping null values

# %%
df.dropna()
# Out:
#     Unnamed: 0  area        prices
# 0            0  1000  3.164041e+05
# 1            1  1500  3.842979e+05
# 2            2  2300  4.929281e+05
# 3            3  3540  6.613048e+05
# 4            4  4120  7.400616e+05
# 5            5  4560  7.998082e+05
# 6            6  5490  9.260908e+05
# 7            7  3460  6.504418e+05
# 8            8  4750  8.256079e+05
# 9            9  2300  4.929281e+05
# 10          10  9000  1.402705e+06
# 11          11  8600  1.348390e+06
# 12          12  7100  1.144709e+06

# %% [markdown]
# ### Filling missing values

# %%
df.fillna('something')
# Out:
#     Unnamed: 0  area        prices
# 0            0  1000  3.164041e+05
# 1            1  1500  3.842979e+05
# 2            2  2300  4.929281e+05
# 3            3  3540  6.613048e+05
# 4            4  4120  7.400616e+05
# 5            5  4560  7.998082e+05
# 6            6  5490  9.260908e+05
# 7            7  3460  6.504418e+05
# 8            8  4750  8.256079e+05
# 9            9  2300  4.929281e+05
# 10          10  9000  1.402705e+06
# 11          11  8600  1.348390e+06
# 12          12  7100  1.144709e+06

# %% [markdown]
# ### removing duplicates

# %%
df.drop_duplicates()
# Out:
#     Unnamed: 0  area        prices
# 0            0  1000  3.164041e+05
# 1            1  1500  3.842979e+05
# 2            2  2300  4.929281e+05
# 3            3  3540  6.613048e+05
# 4            4  4120  7.400616e+05
# 5            5  4560  7.998082e+05
# 6            6  5490  9.260908e+05
# 7            7  3460  6.504418e+05
# 8            8  4750  8.256079e+05
# 9            9  2300  4.929281e+05
# 10          10  9000  1.402705e+06
# 11          11  8600  1.348390e+06
# 12          12  7100  1.144709e+06

# %% [markdown]
# ### replacing values

# %%
df.replace({1000:1300},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  area         prices
# 0           0  1300  316404.109589
# 1           1  1200  384297.945205
# 2           2  2300  492928.082192
# 3           3  3540  661304.794521
# 4           4  4120  740061.643836

# %% [markdown]
# ## Renaming columns

# %%
df.rename(columns={'Unnamed: 0':'S#',},inplace=True)
df.head()
# Out:
#    S#  area          price
# 0   0  1300  316404.109589
# 1   1  1200  384297.945205
# 2   2  2300  492928.082192
# 3   3  3540  661304.794521
# 4   4  4120  740061.643836

# %% [markdown]
# ### Adding new column

# %%
df['price/area'] = df['price']/df['area']
df.head()
# Out:
#    S#  area          price  price/area
# 0   0  1300  316404.109589  243.387777
# 1   1  1200  384297.945205  320.248288
# 2   2  2300  492928.082192  214.316557
# 3   3  3540  661304.794521  186.809264
# 4   4  4120  740061.643836  179.626613

# %% [markdown]
# ### dropping columns

# %%
df.drop('S#',axis='columns',inplace=True)
df.head()
# Out:
#    area          price  price/area
# 0  1300  316404.109589  243.387777
# 1  1200  384297.945205  320.248288
# 2  2300  492928.082192  214.316557
# 3  3540  661304.794521  186.809264
# 4  4120  740061.643836  179.626613

# %% [markdown]
# ### Filterring row

# %%
df[df.area>1200]
# Out:
#     area         price  price/area
# 0   1300  3.164041e+05  243.387777
# 2   2300  4.929281e+05  214.316557
# 3   3540  6.613048e+05  186.809264
# 4   4120  7.400616e+05  179.626613
# 5   4560  7.998082e+05  175.396539
# 6   5490  9.260908e+05  168.686840
# 7   3460  6.504418e+05  187.988954
# 8   4750  8.256079e+05  173.812185
# 9   2300  4.929281e+05  214.316557
# 10  9000  1.402705e+06  155.856164
# 11  8600  1.348390e+06  156.789583
# 12  7100  1.144709e+06  161.226606

# %% [markdown]
# ### Sorting values

# %%
df.sort_values('area',ascending=True,inplace=True)
df.head()
# Out:
#    area          price  price/area
# 1  1200  384297.945205  320.248288
# 0  1300  316404.109589  243.387777
# 2  2300  492928.082192  214.316557
# 9  2300  492928.082192  214.316557
# 7  3460  650441.780822  187.988954

# %% [markdown]
# ###Group by

# %%
grouped_data=df.groupby('price')
grouped_data.describe()
# Out:
#               area                                                       \
#              count    mean  std     min     25%     50%     75%     max
# price
# 3.164041e+05   1.0  1300.0  NaN  1300.0  1300.0  1300.0  1300.0  1300.0
# 3.842979e+05   1.0  1200.0  NaN  1200.0  1200.0  1200.0  1200.0  1200.0
# 4.929281e+05   2.0  2300.0  0.0  2300.0  2300.0  2300.0  2300.0  2300.0
# 6.504418e+05   1.0  3460.0  NaN  3460.0  3460.0  3460.0  3460.0  3460.0
# 6.613048e+05   1.0  3540.0  NaN  3540.0  3540.0  3540.0  3540.0  3540.0
# 7.400616e+05   1.0  4120.0  NaN  4120.0  4120.0  4120.0  4120.0  4120.0
# 7.998082e+05   1.0  4560.0  NaN  4560.0  4560.0  4560.0  4560.0  4560.0
# 8.256079e+05   1.0  4750.0  NaN  4750.0  4750.0  4750.0  4750.0  4750.0
# 9.260908e+05   1.0  5490.0  NaN  5490.0  5490.0  5490.0  5490.0  5490.0
# 1.144709e+06   1.0  7100.0  NaN  7100.0  7100.0  7100.0  7100.0  7100.0
# 1.348390e+06   1.0  8600.0  NaN  8600.0  8600.0  8600.0  8600.0  8600.0
# ...

# %% [markdown]
# ## Merging data

# %%
left = pd.DataFrame({'ID': [1, 2], 'Name': ['Alice', 'Bob']})
right = pd.DataFrame({'ID': [1, 2], 'City': ['New York', 'Paris']})

# Merge on common column 'ID'
merged_df = pd.merge(left, right, on='ID')
print(merged_df)
# Out:
#    ID   Name      City
# 0   1  Alice  New York
# 1   2    Bob     Paris

# %% [markdown]
# ## Visualization in pandas

# %% [markdown]
# ### Line plot

# %%
df.plot('area','price',kind='line')
# Out:
# <Axes: xlabel='area'>

# %% [markdown]
# ### Bar plot

# %%
df.plot(x='area',y='price',kind='bar')
# Out:
# <Axes: xlabel='area'>

# %%
df.plot(x='area',y='price',kind='scatter')
# Out:
# <Axes: xlabel='area', ylabel='price'>
