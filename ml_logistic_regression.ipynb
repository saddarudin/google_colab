# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('insurance_data.csv')
df.head(10)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1
# 5   56                 1
# 6   55                 0
# 7   60                 1
# 8   62                 1
# 9   61                 1

# %%
plt.scatter(df.age,df.bought_insurance)
plt.title('Age VS Insurance Graph')
plt.xlabel('Age')
plt.ylabel('Insurance')
plt.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.20,random_state=10)
print(x_train.shape)
print(y_train.shape)
# Out:
# (21, 1)
# (21,)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 1, 0, 0, 0, 0])

# %%
y_test
# Out:
# 7     1
# 5     1
# 18    0
# 21    0
# 11    0
# 1     0
# Name: bought_insurance, dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ### Exercise
#
# Consider file HR_Data.csv
# 1.   Do some EDA to figure out which variables have clear and direct impact on
# 2.   Plot bar chart showing impact of employee salaries on retention
# 3.   Plot bar chart showing corelation between department and employee retention
# 4.   Now build logistic regression model using variables that were narrowed down in step1
# 5.   Measure the accuracy of the model

# %%
df1 = pd.read_csv('HR_data.csv')
df1.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df1.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df1.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df1.Work_accident.value_counts()
# Out:
# Work_accident
# 0    12830
# 1     2169
# Name: count, dtype: int64

# %%
df1.promotion_last_5years.value_counts()
# Out:
# promotion_last_5years
# 0    14680
# 1      319
# Name: count, dtype: int64

# %%
pd.crosstab(df1.salary,df1.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df1.Department,df1.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>
