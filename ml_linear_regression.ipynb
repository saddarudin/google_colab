# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv('homeprice.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price,color='red',marker='+')
plt.xlabel('area')
plt.ylabel('price')
plt.title('Area VS Price Plot')
plt.show()

# %%
model = linear_model.LinearRegression()
model.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
model.predict([[3300]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %% [markdown]
# ## Exercise

# %%
df1 = pd.read_csv('canada_per_capita_income.csv')
df1.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df1.rename(columns={'per capita income (US$)':'pci'},inplace=True)
df1.head()
# Out:
#    year          pci
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
plt.scatter(df1.year,df1.pci,color='red')
plt.xlabel('year')
plt.ylabel('pci')
plt.title('Year VS Per Capita Income Plot')
plt.show()

# %%
model1 = linear_model.LinearRegression()
model1.fit(df1[['year']],df1.pci)
# Out:
# LinearRegression()

# %%
model1.predict([[2020]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
model1.predict([[2009]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([32175.57826697])
